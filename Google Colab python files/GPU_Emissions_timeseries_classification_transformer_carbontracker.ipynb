# %% [markdown]
# # Timeseries classification with a Transformer model
#
# **Author:** [Theodoros Ntakouris](https://github.com/ntakouris)<br>
# **Date created:** 2021/06/25<br>
# **Last modified:** 2021/08/05<br>
# **Description:** This notebook demonstrates how to do timeseries classification using a Transformer model.

# %% [markdown]
# ## Introduction
#
# This is the Transformer architecture from
# [Attention Is All You Need](https://arxiv.org/abs/1706.03762),
# applied to timeseries instead of natural language.
#
# This example requires TensorFlow 2.4 or higher.
#
# ## Load the dataset
#
# We are going to use the same dataset and preprocessing as the
# [TimeSeries Classification from Scratch](https://keras.io/examples/timeseries/timeseries_classification_from_scratch)
# example.

# %%
import numpy as np
import keras
from keras import layers


def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)


root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

x_train, y_train = readucr(root_url + "FordA_TRAIN.tsv")
x_test, y_test = readucr(root_url + "FordA_TEST.tsv")

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

n_classes = len(np.unique(y_train))

idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %% [markdown]
# ## Build the model
#
# Our model processes a tensor of shape `(batch size, sequence length, features)`,
# where `sequence length` is the number of time steps and `features` is each input
# timeseries.
#
# You can replace your classification RNN layers with this one: the
# inputs are fully compatible!
#
# We include residual connections, layer normalization, and dropout.
# The resulting layer can be stacked multiple times.
#
# The projection layers are implemented through `keras.layers.Conv1D`.

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(res)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

# %% [markdown]
# The main part of our model is now complete. We can stack multiple of those
# `transformer_encoder` blocks and we can also proceed to add the final
# Multi-Layer Perceptron classification head. Apart from a stack of `Dense`
# layers, we need to reduce the output tensor of the `TransformerEncoder` part of
# our model down to a vector of features for each data point in the current
# batch. A common way to achieve this is to use a pooling layer. For
# this example, a `GlobalAveragePooling1D` layer is sufficient.

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(n_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)

# %% [markdown]
# ## Train and evaluate

# %%
input_shape = x_train.shape[1:]

model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["sparse_categorical_accuracy"],
)
model.summary()

callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 500, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 500, 1)    │      7,169 │ input_layer[0][0… │
# │ (MultiHeadAttentio… │                   │            │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 500, 1)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 500, 1)    │          2 │ dropout_1[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 500, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 500, 4)    │          8 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 500, 4)    │          0 │ conv1d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 500, 1)    │          5 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 500, 1)    │          2 │ conv1d_1[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 500, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 500, 1)    │      7,169 │ add_1[0][0],      │
# │ (MultiHeadAttentio… │                   │            │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 500, 1)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 500, 1)    │          2 │ dropout_4[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 500, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 500, 4)    │          8 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 500, 4)    │          0 │ conv1d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 500, 1)    │          5 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 500, 1)    │          2 │ conv1d_3[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 500, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 500, 1)    │      7,169 │ add_3[0][0],      │
# │ (MultiHeadAttentio… │                   │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 500, 1)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 500, 1)    │          2 │ dropout_7[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 500, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 500, 4)    │          8 │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 500, 4)    │          0 │ conv1d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 500, 1)    │          5 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 500, 1)    │          2 │ conv1d_5[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 500, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 500, 1)    │      7,169 │ add_5[0][0],      │
# │ (MultiHeadAttentio… │                   │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 500, 1)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 500, 1)    │          2 │ dropout_10[0][0]  │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 500, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 500, 4)    │          8 │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 500, 4)    │          0 │ conv1d_6[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 500, 1)    │          5 │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 500, 1)    │          2 │ conv1d_7[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 500, 1)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1)         │          0 │ add_7[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │        256 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 128)       │          0 │ dense[0][0]       │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 2)         │        258 │ dropout_12[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 29,258 (114.29 KB)
#  Trainable params: 29,258 (114.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #Calculating carbon emissions during model training

# %%
# !pip install carbontracker
from carbontracker.tracker import CarbonTracker
# Out:
# Collecting carbontracker
#   Downloading carbontracker-2.1.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from carbontracker) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from carbontracker) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from carbontracker) (2.2.2)
# Requirement already satisfied: geocoder in /usr/local/lib/python3.11/dist-packages (from carbontracker) (1.38.1)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.11/dist-packages (from carbontracker) (12.0.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from carbontracker) (5.9.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from carbontracker) (8.7.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from geocoder->carbontracker) (8.1.8)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from geocoder->carbontracker) (1.0.0)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.11/dist-packages (from geocoder->carbontracker) (0.1.6)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from geocoder->carbontracker) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->carbontracker) (3.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->carbontracker) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->carbontracker) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->carbontracker) (2025.2)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.11/dist-packages (from pynvml->carbontracker) (12.570.86)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->carbontracker) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->carbontracker) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->carbontracker) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->carbontracker) (2025.4.26)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ratelim->geocoder->carbontracker) (4.4.2)
# Downloading carbontracker-2.1.2-py3-none-any.whl (39 kB)
# Installing collected packages: carbontracker
# Successfully installed carbontracker-2.1.2

# %%
#model.fit(
#    x_train,
#    y_train,
#    validation_split=0.2,
#    epochs=150,
#    batch_size=64,
#    callbacks=callbacks,
#)

#model.evaluate(x_test, y_test, verbose=1)

# %%
# Initialize the tracker for 150 epochs
tracker = CarbonTracker(epochs=150)

for epoch in range(150):
    tracker.epoch_start()  # start tracking this epoch

    model.fit(
        x_train,
        y_train,
        validation_split=0.2,
        epochs=1,            # train only one epoch at a time
        batch_size=64,
        callbacks=callbacks,
    )

    tracker.epoch_end()    # end tracking this epoch

tracker.stop()             # stop the tracker after all epochs

# After training, evaluate the model
model.evaluate(x_test, y_test, verbose=1)
# Out:
# CarbonTracker: The following components were found: GPU with device(s) Tesla T4.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 369.47318 gCO2/kWh.
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 50s 372ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5030 - val_loss: 0.6929 - val_sparse_categorical_accuracy: 0.5326
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 369.47318 gCO2/kWh.
# CarbonTracker: Live carbon intensity could not be fetched at detected location: Las Vegas, Nevada, US. Defaulted to average carbon intensity for US in 2023 of 369.47 gCO2/kWh. at detected location: Las Vegas, Nevada, US.
# CarbonTracker:
# Predicted consumption for 150 epoch(s):
# 	Time:	2:26:57
# 	Energy:	0.156362951375 kWh
# 	CO2eq:	57.771916878640 g
# 	This is equivalent to:
# 	0.537413180266 km travelled by car
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 14s 312ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5149 - val_loss: 0.6928 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 14s 313ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5017 - val_loss: 0.6927 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 14s 315ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5111 - val_loss: 0.6927 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 14s 316ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.4994 - val_loss: 0.6926 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 14s 319ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5148 - val_loss: 0.6925 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 14s 319ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5138 - val_loss: 0.6925 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 15s 325ms/step - loss: 0.6933 - sparse_categorical_accuracy: 0.4980 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 15s 329ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5052 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 15s 329ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5053 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 15s 333ms/step - loss: 0.6934 - sparse_categorical_accuracy: 0.4984 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 15s 331ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5087 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 15s 333ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5057 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 15s 333ms/step - loss: 0.6926 - sparse_categorical_accuracy: 0.5248 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 15s 336ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5048 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 15s 335ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5110 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 15s 336ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5021 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 365ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5035 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 368ms/step - loss: 0.6933 - sparse_categorical_accuracy: 0.4955 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 15s 338ms/step - loss: 0.6924 - sparse_categorical_accuracy: 0.5308 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 372ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5143 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 352ms/step - loss: 0.6926 - sparse_categorical_accuracy: 0.5223 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 373ms/step - loss: 0.6933 - sparse_categorical_accuracy: 0.4992 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 373ms/step - loss: 0.6933 - sparse_categorical_accuracy: 0.4978 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 352ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5109 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 380ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5097 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 374ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5063 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 374ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5127 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 375ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5193 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 346ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5088 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 380ms/step - loss: 0.6933 - sparse_categorical_accuracy: 0.5026 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 348ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5016 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 371ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5010 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 347ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5077 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 354ms/step - loss: 0.6927 - sparse_categorical_accuracy: 0.5188 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 346ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5055 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 373ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5045 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 349ms/step - loss: 0.6933 - sparse_categorical_accuracy: 0.5032 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 347ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5048 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 349ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5113 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 372ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5116 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 348ms/step - loss: 0.6934 - sparse_categorical_accuracy: 0.4932 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 347ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5060 - val_loss: 0.6921 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 349ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5132 - val_loss: 0.6921 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 346ms/step - loss: 0.6927 - sparse_categorical_accuracy: 0.5168 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 376ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5134 - val_loss: 0.6921 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 346ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5088 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 369.47318 gCO2/kWh.
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 351ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5073 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 351ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5102 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 375ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5102 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 15s 344ms/step - loss: 0.6927 - sparse_categorical_accuracy: 0.5211 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 348ms/step - loss: 0.6927 - sparse_categorical_accuracy: 0.5201 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 351ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5220 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 347ms/step - loss: 0.6934 - sparse_categorical_accuracy: 0.4991 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 344ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5032 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 346ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5084 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 353ms/step - loss: 0.6935 - sparse_categorical_accuracy: 0.4896 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 376ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5016 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 371ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5067 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 373ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5068 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 352ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5066 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 375ms/step - loss: 0.6927 - sparse_categorical_accuracy: 0.5186 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 347ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5143 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 348ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5020 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 345ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5071 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 347ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.4991 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 346ms/step - loss: 0.6934 - sparse_categorical_accuracy: 0.4971 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 377ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5135 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 376ms/step - loss: 0.6928 - sparse_categorical_accuracy: 0.5143 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 347ms/step - loss: 0.6935 - sparse_categorical_accuracy: 0.4946 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 351ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5096 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 350ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5095 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 15s 344ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5021 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 375ms/step - loss: 0.6928 - sparse_categorical_accuracy: 0.5141 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 375ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5002 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 376ms/step - loss: 0.6936 - sparse_categorical_accuracy: 0.4877 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 348ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5092 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 379ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5209 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 345ms/step - loss: 0.6933 - sparse_categorical_accuracy: 0.4983 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 345ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5161 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 348ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5048 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 349ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5107 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 347ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5148 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 346ms/step - loss: 0.6927 - sparse_categorical_accuracy: 0.5142 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 15s 343ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5141 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 350ms/step - loss: 0.6928 - sparse_categorical_accuracy: 0.5168 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 379ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5092 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 375ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5148 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 346ms/step - loss: 0.6928 - sparse_categorical_accuracy: 0.5152 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 349ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5022 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 377ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5063 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 349ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5006 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 377ms/step - loss: 0.6934 - sparse_categorical_accuracy: 0.4978 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 346ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5045 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 374ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5012 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 369.47318 gCO2/kWh.
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 375ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5054 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 374ms/step - loss: 0.6927 - sparse_categorical_accuracy: 0.5169 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 350ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5014 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 375ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5001 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 372ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5127 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 378ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5070 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 347ms/step - loss: 0.6927 - sparse_categorical_accuracy: 0.5190 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 348ms/step - loss: 0.6934 - sparse_categorical_accuracy: 0.4981 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 345ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5096 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 379ms/step - loss: 0.6933 - sparse_categorical_accuracy: 0.4990 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 350ms/step - loss: 0.6934 - sparse_categorical_accuracy: 0.4956 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 372ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5112 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 374ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5074 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 382ms/step - loss: 0.6933 - sparse_categorical_accuracy: 0.5004 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 346ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5073 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 374ms/step - loss: 0.6933 - sparse_categorical_accuracy: 0.4951 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 353ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5142 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 348ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5203 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 372ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5186 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 350ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5089 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 379ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5214 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 373ms/step - loss: 0.6935 - sparse_categorical_accuracy: 0.4910 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 377ms/step - loss: 0.6935 - sparse_categorical_accuracy: 0.4958 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 348ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5138 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 349ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5105 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 345ms/step - loss: 0.6933 - sparse_categorical_accuracy: 0.5002 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 350ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5287 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 377ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5061 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 350ms/step - loss: 0.6933 - sparse_categorical_accuracy: 0.5008 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 373ms/step - loss: 0.6936 - sparse_categorical_accuracy: 0.4937 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 346ms/step - loss: 0.6928 - sparse_categorical_accuracy: 0.5167 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 379ms/step - loss: 0.6927 - sparse_categorical_accuracy: 0.5170 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 377ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5063 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 346ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5104 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 372ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5103 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 375ms/step - loss: 0.6928 - sparse_categorical_accuracy: 0.5156 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 381ms/step - loss: 0.6935 - sparse_categorical_accuracy: 0.4923 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 375ms/step - loss: 0.6929 - sparse_categorical_accuracy: 0.5109 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 374ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5116 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 374ms/step - loss: 0.6935 - sparse_categorical_accuracy: 0.4937 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 377ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.5047 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 346ms/step - loss: 0.6933 - sparse_categorical_accuracy: 0.5042 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 346ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5024 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 349ms/step - loss: 0.6925 - sparse_categorical_accuracy: 0.5206 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 348ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.5030 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 374ms/step - loss: 0.6927 - sparse_categorical_accuracy: 0.5150 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 352ms/step - loss: 0.6928 - sparse_categorical_accuracy: 0.5150 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 350ms/step - loss: 0.6922 - sparse_categorical_accuracy: 0.5362 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 41/45 ━━━━━━━━━━━━━━━━━━━━ 1s 314ms/step - loss: 0.6926 - sparse_categorical_accuracy: 0.5206CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 369.47318 gCO2/kWh.
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 374ms/step - loss: 0.6926 - sparse_categorical_accuracy: 0.5192 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 370ms/step - loss: 0.6926 - sparse_categorical_accuracy: 0.5220 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 351ms/step - loss: 0.6935 - sparse_categorical_accuracy: 0.4956 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 383ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.5123 - val_loss: 0.6924 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 373ms/step - loss: 0.6934 - sparse_categorical_accuracy: 0.4922 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 16s 345ms/step - loss: 0.6934 - sparse_categorical_accuracy: 0.4976 - val_loss: 0.6923 - val_sparse_categorical_accuracy: 0.5326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 17s 379ms/step - loss: 0.6924 - sparse_categorical_accuracy: 0.5250 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5326
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 369.47318 gCO2/kWh.
# CarbonTracker: Average carbon intensity during training was 369.47 gCO2/kWh at detected location: Las Vegas, Nevada, US.
# CarbonTracker:
# Actual consumption for 150 epoch(s):
# 	Time:	0:47:03
# 	Energy:	0.079341174277 kWh
# 	CO2eq:	29.314435965158 g
# 	This is equivalent to:
# 	0.272692427583 km travelled by car
# CarbonTracker: Finished monitoring.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 0.6923 - sparse_categorical_accuracy: 0.5299
# [0.6927468776702881, 0.5159090757369995]

# %% [markdown]
# ## Conclusions
#
# In about 110-120 epochs (25s each on Colab), the model reaches a training
# accuracy of ~0.95, validation accuracy of ~84 and a testing
# accuracy of ~85, without hyperparameter tuning. And that is for a model
# with less than 100k parameters. Of course, parameter count and accuracy could be
# improved by a hyperparameter search and a more sophisticated learning rate
# schedule, or a different optimizer.
