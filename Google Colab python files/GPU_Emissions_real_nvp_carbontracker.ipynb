# %% [markdown]
# # Density estimation using Real NVP
#
# **Authors:** [Mandolini Giorgio Maria](https://www.linkedin.com/in/giorgio-maria-mandolini-a2a1b71b4/), [Sanna Daniele](https://www.linkedin.com/in/daniele-sanna-338629bb/), [Zannini Quirini Giorgio](https://www.linkedin.com/in/giorgio-zannini-quirini-16ab181a0/)<br>
# **Date created:** 2020/08/10<br>
# **Last modified:** 2020/08/10<br>
# **Description:** Estimating the density distribution of the "double moon" dataset.

# %% [markdown]
# ## Introduction
#
# The aim of this work is to map a simple distribution - which is easy to sample
# and whose density is simple to estimate - to a more complex one learned from the data.
# This kind of generative model is also known as "normalizing flow".
#
# In order to do this, the model is trained via the maximum
# likelihood principle, using the "change of variable" formula.
#
# We will use an affine coupling function. We create it such that its inverse, as well as
# the determinant of the Jacobian, are easy to obtain (more details in the referenced paper).
#
# **Requirements:**
#
# * Tensorflow 2.9.1
# * Tensorflow probability 0.17.0
#
# **Reference:**
#
# [Density estimation using Real NVP](https://arxiv.org/abs/1605.08803)

# %% [markdown]
# ## Setup

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.datasets import make_moons
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_probability as tfp

# %% [markdown]
# ## Load the data

# %%
data = make_moons(3000, noise=0.05)[0].astype("float32")
norm = layers.Normalization()
norm.adapt(data)
normalized_data = norm(data)

# %% [markdown]
# ## Affine coupling layer

# %%
# Creating a custom layer with keras API.
output_dim = 256
reg = 0.01


def Coupling(input_shape):
#    input = keras.layers.Input(shape=input_shape)
    input = keras.layers.Input(shape=(input_shape,))

    t_layer_1 = keras.layers.Dense(
        output_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(input)
    t_layer_2 = keras.layers.Dense(
        output_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(t_layer_1)
    t_layer_3 = keras.layers.Dense(
        output_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(t_layer_2)
    t_layer_4 = keras.layers.Dense(
        output_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(t_layer_3)
    t_layer_5 = keras.layers.Dense(
        input_shape, activation="linear", kernel_regularizer=regularizers.l2(reg)
    )(t_layer_4)

    s_layer_1 = keras.layers.Dense(
        output_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(input)
    s_layer_2 = keras.layers.Dense(
        output_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(s_layer_1)
    s_layer_3 = keras.layers.Dense(
        output_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(s_layer_2)
    s_layer_4 = keras.layers.Dense(
        output_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(s_layer_3)
    s_layer_5 = keras.layers.Dense(
        input_shape, activation="tanh", kernel_regularizer=regularizers.l2(reg)
    )(s_layer_4)

    return keras.Model(inputs=input, outputs=[s_layer_5, t_layer_5])

# %% [markdown]
# ## Real NVP

# %%
class RealNVP(keras.Model):
    def __init__(self, num_coupling_layers):
        super().__init__()

        self.num_coupling_layers = num_coupling_layers

        # Distribution of the latent space.
        self.distribution = tfp.distributions.MultivariateNormalDiag(
            loc=[0.0, 0.0], scale_diag=[1.0, 1.0]
        )
        self.masks = np.array(
            [[0, 1], [1, 0]] * (num_coupling_layers // 2), dtype="float32"
        )
        self.loss_tracker = keras.metrics.Mean(name="loss")
        self.layers_list = [Coupling(2) for i in range(num_coupling_layers)]

    @property
    def metrics(self):
        """List of the model's metrics.

        We make sure the loss tracker is listed as part of `model.metrics`
        so that `fit()` and `evaluate()` are able to `reset()` the loss tracker
        at the start of each epoch and at the start of an `evaluate()` call.
        """
        return [self.loss_tracker]

    def call(self, x, training=True):
        log_det_inv = 0
        direction = 1
        if training:
            direction = -1
        for i in range(self.num_coupling_layers)[::direction]:
            x_masked = x * self.masks[i]
            reversed_mask = 1 - self.masks[i]
            s, t = self.layers_list[i](x_masked)
            s *= reversed_mask
            t *= reversed_mask
            gate = (direction - 1) / 2
            x = (
                reversed_mask
                * (x * tf.exp(direction * s) + direction * t * tf.exp(gate * s))
                + x_masked
            )
            log_det_inv += gate * tf.reduce_sum(s, [1])

        return x, log_det_inv

    # Log likelihood of the normal distribution plus the log determinant of the jacobian.

    def log_loss(self, x):
        y, logdet = self(x)
        log_likelihood = self.distribution.log_prob(y) + logdet
        return -tf.reduce_mean(log_likelihood)

    def train_step(self, data):
        with tf.GradientTape() as tape:

            loss = self.log_loss(data)

        g = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(g, self.trainable_variables))
        self.loss_tracker.update_state(loss)

        return {"loss": self.loss_tracker.result()}

    def test_step(self, data):
        loss = self.log_loss(data)
        self.loss_tracker.update_state(loss)

        return {"loss": self.loss_tracker.result()}

# %% [markdown]
# ## Model training

# %%
model = RealNVP(num_coupling_layers=6)

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0001))

# %% [markdown]
# #Calculating carbon emissions during model training

# %%
# !pip install carbontracker
from carbontracker.tracker import CarbonTracker
# Out:
# Collecting carbontracker
#   Downloading carbontracker-2.1.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from carbontracker) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from carbontracker) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from carbontracker) (2.2.2)
# Requirement already satisfied: geocoder in /usr/local/lib/python3.11/dist-packages (from carbontracker) (1.38.1)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.11/dist-packages (from carbontracker) (12.0.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from carbontracker) (5.9.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from carbontracker) (8.7.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from geocoder->carbontracker) (8.1.8)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from geocoder->carbontracker) (1.0.0)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.11/dist-packages (from geocoder->carbontracker) (0.1.6)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from geocoder->carbontracker) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->carbontracker) (3.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->carbontracker) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->carbontracker) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->carbontracker) (2025.2)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.11/dist-packages (from pynvml->carbontracker) (12.570.86)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->carbontracker) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->carbontracker) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->carbontracker) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->carbontracker) (2025.4.26)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ratelim->geocoder->carbontracker) (4.4.2)
# Downloading carbontracker-2.1.2-py3-none-any.whl (39 kB)
# Installing collected packages: carbontracker
# Successfully installed carbontracker-2.1.2

# %%
#history = model.fit(
#    normalized_data, batch_size=256, epochs=300, verbose=2, validation_split=0.2
#)

# %%
total_epochs = 300
tracker = CarbonTracker(epochs=total_epochs)

history_list = []

for epoch in range(total_epochs):
    tracker.epoch_start()

    history = model.fit(
        normalized_data,
        batch_size=256,
        epochs=1,               # run one epoch at a time
        verbose=2,
        validation_split=0.2
    )
    history_list.append(history)

    tracker.epoch_end()

tracker.stop()
# Out:
# CarbonTracker: The following components were found: GPU with device(s) Tesla T4.
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 369.47318 gCO2/kWh.
# 10/10 - 39s - 4s/step - loss: 2.6949 - val_loss: 2.6507
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 369.47318 gCO2/kWh.
# CarbonTracker: Live carbon intensity could not be fetched at detected location: North Charleston, South Carolina, US. Defaulted to average carbon intensity for US in 2023 of 369.47 gCO2/kWh. at detected location: North Charleston, South Carolina, US.
# CarbonTracker:
# Predicted consumption for 300 epoch(s):
# 	Time:	3:37:36
# 	Energy:	0.165571328950 kWh
# 	CO2eq:	61.174165423845 g
# 	This is equivalent to:
# 	0.569062003943 km travelled by car
# 10/10 - 0s - 31ms/step - loss: 2.6161 - val_loss: 2.5827
# 10/10 - 0s - 25ms/step - loss: 2.5536 - val_loss: 2.5358
# 10/10 - 0s - 24ms/step - loss: 2.5049 - val_loss: 2.5094
# 10/10 - 0s - 25ms/step - loss: 2.4751 - val_loss: 2.4914
# 10/10 - 0s - 24ms/step - loss: 2.4394 - val_loss: 2.4596
# 10/10 - 0s - 23ms/step - loss: 2.4042 - val_loss: 2.4374
# 10/10 - 0s - 24ms/step - loss: 2.3759 - val_loss: 2.4148
# 10/10 - 0s - 23ms/step - loss: 2.3504 - val_loss: 2.3963
# 10/10 - 0s - 23ms/step - loss: 2.3262 - val_loss: 2.3751
# 10/10 - 0s - 24ms/step - loss: 2.3024 - val_loss: 2.3555
# 10/10 - 0s - 27ms/step - loss: 2.2735 - val_loss: 2.3373
# 10/10 - 0s - 26ms/step - loss: 1.1794 - val_loss: 1.4973
# 10/10 - 0s - 22ms/step - loss: 1.1746 - val_loss: 1.4234
# 10/10 - 0s - 23ms/step - loss: 1.1938 - val_loss: 1.4573
# 10/10 - 0s - 28ms/step - loss: 1.2394 - val_loss: 1.4288
# 10/10 - 0s - 28ms/step - loss: 1.2329 - val_loss: 1.3183
# 10/10 - 0s - 23ms/step - loss: 1.2327 - val_loss: 1.4343
# 10/10 - 0s - 21ms/step - loss: 1.2322 - val_loss: 1.3785
# 10/10 - 0s - 22ms/step - loss: 1.1653 - val_loss: 1.3464
# 10/10 - 0s - 22ms/step - loss: 1.1680 - val_loss: 1.3552
# 10/10 - 0s - 26ms/step - loss: 1.1762 - val_loss: 1.4131
# 10/10 - 0s - 23ms/step - loss: 1.1601 - val_loss: 1.3460
# 10/10 - 0s - 22ms/step - loss: 1.1795 - val_loss: 1.3675
# 10/10 - 0s - 22ms/step - loss: 1.1763 - val_loss: 1.3724
# 10/10 - 0s - 23ms/step - loss: 1.1700 - val_loss: 1.3448
# 10/10 - 0s - 22ms/step - loss: 1.1886 - val_loss: 1.3611
# 10/10 - 0s - 26ms/step - loss: 1.1633 - val_loss: 1.3986
# 10/10 - 0s - 22ms/step - loss: 1.1675 - val_loss: 1.3791
# 10/10 - 0s - 26ms/step - loss: 1.1790 - val_loss: 1.4051
# 10/10 - 0s - 23ms/step - loss: 1.1924 - val_loss: 1.3865
# 10/10 - 0s - 23ms/step - loss: 1.1709 - val_loss: 1.3420
# 10/10 - 0s - 22ms/step - loss: 1.2703 - val_loss: 1.5083
# 10/10 - 0s - 27ms/step - loss: 1.2224 - val_loss: 1.3099
# 10/10 - 0s - 22ms/step - loss: 1.1931 - val_loss: 1.3862
# 10/10 - 0s - 23ms/step - loss: 1.1808 - val_loss: 1.4042
# 10/10 - 0s - 26ms/step - loss: 1.1686 - val_loss: 1.3427
# 10/10 - 0s - 21ms/step - loss: 1.1524 - val_loss: 1.6299
# 10/10 - 0s - 22ms/step - loss: 1.2097 - val_loss: 1.3717
# 10/10 - 0s - 22ms/step - loss: 1.1833 - val_loss: 1.4061
# 10/10 - 0s - 26ms/step - loss: 1.1978 - val_loss: 1.3890
# 10/10 - 0s - 21ms/step - loss: 1.1946 - val_loss: 1.3250
# 10/10 - 0s - 32ms/step - loss: 1.1816 - val_loss: 1.3592
# 10/10 - 0s - 31ms/step - loss: 1.1726 - val_loss: 1.3187
# 10/10 - 0s - 31ms/step - loss: 1.1727 - val_loss: 1.3830
# 10/10 - 0s - 34ms/step - loss: 1.1963 - val_loss: 1.3650
# 10/10 - 0s - 24ms/step - loss: 1.2011 - val_loss: 1.3435
# 10/10 - 0s - 27ms/step - loss: 1.2106 - val_loss: 1.3972
# 10/10 - 0s - 22ms/step - loss: 1.2239 - val_loss: 1.4093
# 10/10 - 0s - 26ms/step - loss: 1.1900 - val_loss: 1.3711
# 10/10 - 0s - 26ms/step - loss: 1.1894 - val_loss: 1.3670
# 10/10 - 0s - 22ms/step - loss: 1.1916 - val_loss: 1.3641
# 10/10 - 0s - 26ms/step - loss: 1.1646 - val_loss: 1.3538
# 10/10 - 0s - 22ms/step - loss: 1.1666 - val_loss: 1.3378
# 10/10 - 0s - 26ms/step - loss: 1.1895 - val_loss: 1.3969
# 10/10 - 0s - 22ms/step - loss: 1.1947 - val_loss: 1.4070
# 10/10 - 0s - 26ms/step - loss: 1.1763 - val_loss: 1.4039
# 10/10 - 0s - 23ms/step - loss: 1.1835 - val_loss: 1.3352
# 10/10 - 0s - 22ms/step - loss: 1.1638 - val_loss: 1.3824
# 10/10 - 0s - 25ms/step - loss: 1.1866 - val_loss: 1.5085
# 10/10 - 0s - 22ms/step - loss: 1.2314 - val_loss: 1.3533
# 10/10 - 0s - 22ms/step - loss: 1.2043 - val_loss: 1.3874
# 10/10 - 0s - 25ms/step - loss: 1.1782 - val_loss: 1.3624
# 10/10 - 0s - 26ms/step - loss: 1.1701 - val_loss: 1.3391
# 10/10 - 0s - 23ms/step - loss: 1.1477 - val_loss: 1.3543
# 10/10 - 0s - 26ms/step - loss: 1.1749 - val_loss: 1.3397
# 10/10 - 0s - 26ms/step - loss: 1.1900 - val_loss: 1.3829
# 10/10 - 0s - 26ms/step - loss: 1.1869 - val_loss: 1.3755
# 10/10 - 0s - 22ms/step - loss: 1.1630 - val_loss: 1.3540
# 10/10 - 0s - 26ms/step - loss: 1.1568 - val_loss: 1.3612
# 10/10 - 0s - 22ms/step - loss: 1.1685 - val_loss: 1.3369
# 10/10 - 0s - 22ms/step - loss: 1.1724 - val_loss: 1.3864
# 10/10 - 0s - 23ms/step - loss: 1.1626 - val_loss: 1.3635
# 10/10 - 0s - 25ms/step - loss: 1.1669 - val_loss: 1.3780
# 10/10 - 0s - 25ms/step - loss: 1.1664 - val_loss: 1.3675
# 10/10 - 0s - 23ms/step - loss: 1.1479 - val_loss: 1.3977
# 10/10 - 0s - 28ms/step - loss: 1.1559 - val_loss: 1.3403
# 10/10 - 0s - 31ms/step - loss: 1.1706 - val_loss: 1.3981
# 10/10 - 0s - 28ms/step - loss: 1.1720 - val_loss: 1.3311
# 10/10 - 0s - 31ms/step - loss: 1.1792 - val_loss: 1.3697
# 10/10 - 0s - 33ms/step - loss: 1.1603 - val_loss: 1.4924
# 10/10 - 0s - 26ms/step - loss: 1.1661 - val_loss: 1.3735
# 10/10 - 0s - 22ms/step - loss: 1.1735 - val_loss: 1.3752
# 10/10 - 0s - 26ms/step - loss: 1.1801 - val_loss: 1.3142
# 10/10 - 0s - 21ms/step - loss: 1.1608 - val_loss: 1.3736
# 10/10 - 0s - 23ms/step - loss: 1.1532 - val_loss: 1.3364
# 10/10 - 0s - 21ms/step - loss: 1.1483 - val_loss: 1.3970
# 10/10 - 0s - 22ms/step - loss: 1.1619 - val_loss: 1.3697
# 10/10 - 0s - 22ms/step - loss: 1.1438 - val_loss: 1.3935
# 10/10 - 0s - 22ms/step - loss: 1.1491 - val_loss: 1.3413
# 10/10 - 0s - 26ms/step - loss: 1.1580 - val_loss: 1.3586
# 10/10 - 0s - 25ms/step - loss: 1.1616 - val_loss: 1.4303
# 10/10 - 0s - 21ms/step - loss: 1.1622 - val_loss: 1.3919
# 10/10 - 0s - 23ms/step - loss: 1.1840 - val_loss: 1.4212
# 10/10 - 0s - 27ms/step - loss: 1.1910 - val_loss: 1.3253
# 10/10 - 0s - 22ms/step - loss: 1.1833 - val_loss: 1.4009
# 10/10 - 0s - 22ms/step - loss: 1.1553 - val_loss: 1.3286
# 10/10 - 0s - 22ms/step - loss: 1.1750 - val_loss: 1.3781
# 10/10 - 0s - 25ms/step - loss: 1.1895 - val_loss: 1.3335
# 10/10 - 0s - 26ms/step - loss: 1.1808 - val_loss: 1.4183
# 10/10 - 0s - 23ms/step - loss: 1.1564 - val_loss: 1.3258
# 10/10 - 0s - 22ms/step - loss: 1.1677 - val_loss: 1.4228
# 10/10 - 0s - 22ms/step - loss: 1.1670 - val_loss: 1.3324
# 10/10 - 0s - 23ms/step - loss: 1.1728 - val_loss: 1.4933
# 10/10 - 0s - 22ms/step - loss: 1.1673 - val_loss: 1.3738
# 10/10 - 0s - 22ms/step - loss: 1.1886 - val_loss: 1.3230
# 10/10 - 0s - 21ms/step - loss: 1.2223 - val_loss: 1.4555
# 10/10 - 0s - 22ms/step - loss: 1.1842 - val_loss: 1.3142
# 10/10 - 0s - 22ms/step - loss: 1.1766 - val_loss: 1.4056
# CarbonTracker: WARNING - ElectricityMaps API key not set. Will default to average carbon intensity.
# CarbonTracker: WARNING - Failed to retrieve carbon intensity: Defaulting to average carbon intensity 369.47318 gCO2/kWh.
# CarbonTracker: Average carbon intensity during training was 369.47 gCO2/kWh at detected location: North Charleston, South Carolina, US.
# CarbonTracker:
# Actual consumption for 300 epoch(s):
# 	Time:	0:02:24
# 	Energy:	0.002106180585 kWh
# 	CO2eq:	0.778177238297 g
# 	This is equivalent to:
# 	0.007238858031 km travelled by car
# CarbonTracker: Finished monitoring.

# %% [markdown]
# ## Performance evaluation

# %%
plt.figure(figsize=(15, 10))
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.legend(["train", "validation"], loc="upper right")
plt.ylabel("loss")
plt.xlabel("epoch")

# From data to latent space.
z, _ = model(normalized_data)

# From latent space to data.
samples = model.distribution.sample(3000)
x, _ = model.predict(samples)

f, axes = plt.subplots(2, 2)
f.set_size_inches(20, 15)

axes[0, 0].scatter(normalized_data[:, 0], normalized_data[:, 1], color="r")
axes[0, 0].set(title="Inference data space X", xlabel="x", ylabel="y")
axes[0, 1].scatter(z[:, 0], z[:, 1], color="r")
axes[0, 1].set(title="Inference latent space Z", xlabel="x", ylabel="y")
axes[0, 1].set_xlim([-3.5, 4])
axes[0, 1].set_ylim([-4, 4])
axes[1, 0].scatter(samples[:, 0], samples[:, 1], color="g")
axes[1, 0].set(title="Generated latent space Z", xlabel="x", ylabel="y")
axes[1, 1].scatter(x[:, 0], x[:, 1], color="g")
axes[1, 1].set(title="Generated data space X", label="x", ylabel="y")
axes[1, 1].set_xlim([-2, 2])
axes[1, 1].set_ylim([-2, 2])
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step
# (-2.0, 2.0)
